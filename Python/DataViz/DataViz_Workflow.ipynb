# %% [markdown]
# # DataViz workflow

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px

# %%
file = '/content/List of Countries by number of Internet Users - Sheet1.csv'

internet = pd.read_csv(file)


internet.head(10)
# Out:
#   Country or Area  Internet Users  Population  Rank Percentage Rank_pct
# 0           China       765367947  1409517397     1       0.54      116
# 1           India       461347554  1339180127     2       0.34      145
# 2   United States       244090854   324459463     3       0.75       68
# 3          Brazil       141206801   209288278     4       0.67       83
# 4           Japan       115845120   127484450     5       0.91       23
# 5          Russia       109446612   143989754     6       0.76       64
# 6       Indonesia        85242816   263991379     7       0.32      150
# 7          Mexico        82470752   129163276     8       0.64       92
# 8         Germany        69304405    82114224     9       0.84       36
# 9     Philippines        63003313   104918090    10       0.60      103

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  215 non-null    object
#  1   Internet Users   215 non-null    object
#  2   Population       215 non-null    object
#  3   Rank             215 non-null    int64
#  4   Percentage       215 non-null    object
#  5   Rank_pct         215 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 10.2+ KB

# %%
# Check shape
internet.shape
# Out:
# (215, 6)

# %%
# Check if there are repeated entries in Countries column
internet['Country or Area'].duplicated().sum()
# Out:
# 0

# %%
pd.options.display.float_format = '{:,.2f}'.format
internet.describe().round(3)
# Out:
#        Internet Users       Population   Rank  Percentage  Rank_pct
# count          205.00           205.00 205.00      205.00    205.00
# mean    17,869,447.64    36,800,536.98 103.08        0.55    105.44
# std     66,550,740.43   140,517,057.62  59.46        0.28     60.63
# min          5,520.00        11,192.00   1.00        0.01      1.00
# 25%        448,260.00     1,309,632.00  52.00        0.30     54.00
# 50%      2,811,056.00     7,364,883.00 103.00        0.59    105.00
# 75%      9,521,056.00    24,450,561.00 154.00        0.79    158.00
# max    765,367,947.00 1,409,517,397.00 209.00        0.99    209.00

# %%
internet.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_06e73_row0_col0, #T_06e73_row1_col1, #T_06e73_row2_col2, #T_06e73_row3_col3, #T_06e73_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_06e73_row0_col1, #T_06e73_row1_col0 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_06e73_row0_col2, #T_06e73_row2_col0, #T_06e73_row2_col1, #T_06e73_row3_col4, #T_06e73_row4_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_06e73_row0_col3, #T_06e73_row3_col0 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_06e73_row0_col4, #T_06e73_row4_col0 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_06e73_row1_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_06e73_row1_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_06e73_row1_col4 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_06e73_row2_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_06e73_row2_col4 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_06e73_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_06e73_row3_col2 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_06e73_row4_col1 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_06e73_row4_col2 {
#   background-color: #dadce0;
#   color: #000000;
# }
# </style>
# <table id="T_06e73_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Internet Users</th>
#       <th class="col_heading level0 col1" >Population</th>
#       <th class="col_heading level0 col2" >Rank</th>
#       <th class="col_heading level0 col3" >Percentage</th>
#       <th class="col_heading level0 col4" >Rank_pct</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06e73_level0_row0" class="row_heading level0 row0" >Internet Users</th>
#       <td id="T_06e73_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_06e73_row0_col1" class="data row0 col1" >0.959814</td>
#       <td id="T_06e73_row0_col2" class="data row0 col2" >-0.377877</td>
#       <td id="T_06e73_row0_col3" class="data row0 col3" >0.035129</td>
#       <td id="T_06e73_row0_col4" class="data row0 col4" >-0.049747</td>
#     </tr>
#     <tr>
#       <th id="T_06e73_level0_row1" class="row_heading level0 row1" >Population</th>
#       <td id="T_06e73_row1_col0" class="data row1 col0" >0.959814</td>
#       <td id="T_06e73_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_06e73_row1_col2" class="data row1 col2" >-0.350031</td>
#       <td id="T_06e73_row1_col3" class="data row1 col3" >-0.055248</td>
#       <td id="T_06e73_row1_col4" class="data row1 col4" >-0.015487</td>
#     </tr>
#     <tr>
#       <th id="T_06e73_level0_row2" class="row_heading level0 row2" >Rank</th>
#       <td id="T_06e73_row2_col0" class="data row2 col0" >-0.377877</td>
#       <td id="T_06e73_row2_col1" class="data row2 col1" >-0.350031</td>
#       <td id="T_06e73_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_06e73_row2_col3" class="data row2 col3" >-0.127292</td>
#       <td id="T_06e73_row2_col4" class="data row2 col4" >0.295330</td>
#     </tr>
#     <tr>
#       <th id="T_06e73_level0_row3" class="row_heading level0 row3" >Percentage</th>
#       <td id="T_06e73_row3_col0" class="data row3 col0" >0.035129</td>
#       <td id="T_06e73_row3_col1" class="data row3 col1" >-0.055248</td>
#       <td id="T_06e73_row3_col2" class="data row3 col2" >-0.127292</td>
#       <td id="T_06e73_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_06e73_row3_col4" class="data row3 col4" >-0.372852</td>
#     </tr>
#     <tr>
#       <th id="T_06e73_level0_row4" class="row_heading level0 row4" >Rank_pct</th>
#       <td id="T_06e73_row4_col0" class="data row4 col0" >-0.049747</td>
#       <td id="T_06e73_row4_col1" class="data row4 col1" >-0.015487</td>
#       <td id="T_06e73_row4_col2" class="data row4 col2" >0.295330</td>
#       <td id="T_06e73_row4_col3" class="data row4 col3" >-0.372852</td>
#       <td id="T_06e73_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Plot box plots
descr = internet.describe()
descr= internet.describe().T.reset_index().drop('count', axis=1)
descr= pd.melt(descr, id_vars='index', value_vars=descr.iloc[:,1:], var_name='vals')
px.box(descr, y= 'index', x='value', color='index')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3027b85a-acec-426b-a886-c2fb7aa49477" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3027b85a-acec-426b-a886-c2fb7aa49477")) {                    Plotly.newPlot(                        "3027b85a-acec-426b-a886-c2fb7aa49477",                        [{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>value=%{x}<extra></extra>","legendgroup":"Internet Users","marker":{"color":"#636efa"},"name":"Internet Users","notched":false,"offsetgroup":"Internet Users","orientation":"h","showlegend":true,"x":[17869447.63902439,66550740.427291736,5520.0,448260.0,2811056.0,9521056.0,765367947.0],"x0":" ","xaxis":"x","y":["Internet Users","Internet Users","Internet Users","Internet Users","Internet Users","Internet Users","Internet Users"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>value=%{x}<extra></extra>","legendgroup":"Population","marker":{"color":"#EF553B"},"name":"Population","notched":false,"offsetgroup":"Population","orientation":"h","showlegend":true,"x":[36800536.98536585,140517057.62513304,11192.0,1309632.0,7364883.0,24450561.0,1409517397.0],"x0":" ","xaxis":"x","y":["Population","Population","Population","Population","Population","Population","Population"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>value=%{x}<extra></extra>","legendgroup":"Rank","marker":{"color":"#00cc96"},"name":"Rank","notched":false,"offsetgroup":"Rank","orientation":"h","showlegend":true,"x":[103.08292682926829,59.464258100069486,1.0,52.0,103.0,154.0,209.0],"x0":" ","xaxis":"x","y":["Rank","Rank","Rank","Rank","Rank","Rank","Rank"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>value=%{x}<extra></extra>","legendgroup":"Percentage","marker":{"color":"#ab63fa"},"name":"Percentage","notched":false,"offsetgroup":"Percentage","orientation":"h","showlegend":true,"x":[0.5473170731707315,0.28359755030749345,0.01,0.3,0.59,0.79,0.99],"x0":" ","xaxis":"x","y":["Percentage","Percentage","Percentage","Percentage","Percentage","Percentage","Percentage"],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"index=%{y}<br>value=%{x}<extra></extra>","legendgroup":"Rank_pct","marker":{"color":"#FFA15A"},"name":"Rank_pct","notched":false,"offsetgroup":"Rank_pct","orientation":"h","showlegend":true,"x":[105.4390243902439,60.63303667389932,1.0,54.0,105.0,158.0,209.0],"x0":" ","xaxis":"x","y":["Rank_pct","Rank_pct","Rank_pct","Rank_pct","Rank_pct","Rank_pct","Rank_pct"],"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlin ...

# %%
internet.describe()
# Out:
#        Internet Users    Population        Rank  Percentage    Rank_pct
# count    2.050000e+02  2.050000e+02  205.000000  205.000000  205.000000
# mean     1.786945e+07  3.680054e+07  103.082927    0.547317  105.439024
# std      6.655074e+07  1.405171e+08   59.464258    0.283598   60.633037
# min      5.520000e+03  1.119200e+04    1.000000    0.010000    1.000000
# 25%      4.482600e+05  1.309632e+06   52.000000    0.300000   54.000000
# 50%      2.811056e+06  7.364883e+06  103.000000    0.590000  105.000000
# 75%      9.521056e+06  2.445056e+07  154.000000    0.790000  158.000000
# max      7.653679e+08  1.409517e+09  209.000000    0.990000  209.000000

# %% [markdown]
# ### Missing Data

# %%
internet.isnull().sum()
# Out:
# Country or Area    0
# Internet Users     0
# Population         0
# Rank               0
# Percentage         0
# Rank_pct           0
# dtype: int64

# %%
import re

# Check for non-numeric values
non_number = internet.Percentage.apply(lambda x: re.findall('^[1234567890]*', x) != ['0']) 
internet[non_number]
# Out:
#             Country or Area  Internet Users  Population  Rank     Percentage  \
# 197                  Jersey           38958      165314   198  41.03% (2012)
# 201               Gibraltar           32494       34571   202  94.44% (2016)
# 205  British Virgin Islands           14456       31196   206  37.60% (2012)
# 206                Anguilla           12043       14909   207  81.57% (2016)
# 209            Saint Helena            2906        4534   210  37.60% (2012)
# 210        Falkland Islands            2881        2910   211  99.02% (2016)
# 211              Montserrat            2833        5177   212  54.55% (2013)
# 212       Wallis and Futuna            1383       11773   213   8.95% (2012)
# 213                    Niue            1034        1618   214  86.90% (2013)
# 214               Ascension             361         806   215  41.03% (2012)
#
#     Rank_pct
# 197        -
# 201        -
# 205      141
# 206       44
# 209        -
# 210        -
# 211      115
# 212        -
# 213       30
# 214        -

# %%
# Drop those values
internet.drop(internet[non_number].index, axis=0, inplace=True)

# Assign correct value type
internet = internet.astype({'Percentage':float,
                            'Rank_pct': int})

# %%
internet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 0 to 208
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country or Area  205 non-null    object
#  1   Internet Users   205 non-null    int64
#  2   Population       205 non-null    int64
#  3   Rank             205 non-null    int64
#  4   Percentage       205 non-null    float64
#  5   Rank_pct         205 non-null    int64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 11.2+ KB

# %% [markdown]
# ### Relation Plots

# %%
# Pop size vs Internet Users
px.scatter(internet, 
           x= 'Population', y= 'Internet Users',
           size= 'Population', 
           trendline="ols",
           title= "Correlation between Population Size and Internet Users", 
           color= 'Internet Users',
           hover_data=['Country or Area'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ff495299-a5e2-4073-bab6-4c103501c835" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff495299-a5e2-4073-bab6-4c103501c835")) {                    Plotly.newPlot(                        "ff495299-a5e2-4073-bab6-4c103501c835",                        [{"customdata":[["China"],["India"],["United States"],["Brazil"],["Japan"],["Russia"],["Indonesia"],["Mexico"],["Germany"],["Philippines"],["United Kingdom"],["Pakistan"],["France"],["Turkey"],["Iran"],["South Korea"],["Vietnam"],["Egypt"],["Spain"],["Thailand"],["Italy"],["Canada"],["Argentina"],["South Africa"],["Nigeria"],["Colombia"],["Bangladesh"],["Poland"],["Saudi Arabia"],["Malaysia"],["Ukraine"],["Morocco"],["Taiwan"],["Australia"],["Venezuela"],["Algeria"],["Ethiopia"],["Iraq"],["Uzbekistan"],["Myanmar"],["Netherlands"],["Peru"],["Chile"],["Kazakhstan"],["Romania"],["Sudan"],["Ghana"],["Ivory Coast"],["Uganda"],["Belgium"],["Sweden"],["Ecuador"],["Tanzania"],["United Arab Emirates"],["Kenya"],["Czech Republic"],["Switzerland"],["Greece"],["Azerbaijan"],["Austria"],["Portugal"],["Yemen"],["Hungary"],["Sri Lanka"],["Belarus"],["Democratic Republic of the Congo"],["Dominican Republic"],["Guatemala"],["Israel"],["Hong Kong"],["Jordan"],["Tunisia"],["Nepal"],["Syria"],["Serbia"],["Mozambique"],["Cuba"],["Cameroon"],["Denmark"],["Cambodia"],["Norway"],["Bolivia"],["Finland"],["Singapore"],["Zambia"],["Lebanon"],["Senegal"],["Bulgaria"],["Zimbabwe"],["Slovakia"],["New Zealand"],["Angola"],["Paraguay"],["Afghanistan"],["Kuwait"],["Ireland"],["Oman"],["Costa Rica"],["Palestinian Authority"],["Moldova"],["Burkina Faso"],["Honduras"],["Croatia"],["Puerto Rico"],["Rwanda"],["Malawi"],["Qatar"],["Madagascar"],["Bosnia and Herzegovina"],["Panama"],["Georgia"],["Uruguay"],["Mali"],["Kyrgyzstan"],["Lithuania"],["Niger"],["Albania"],["Armenia"],["El Salvador"],["Tajikistan"],["Laos"],["Nicaragua"],["Slovenia"],["Macedonia"],["Latvia"],["Benin"],["Guinea"],["Bahrain"],["Jamaica"],["Libya"],["Haiti"],["Turkmenistan"],["Estonia"],["Trinidad and Tobago"],["Gabon"],["South Sudan"],["Sierra Leone"],["Chad"],["Togo"],["Cyprus"],["Botswana"],["Namibia"],["Papua New Guinea"],["Mauritania"],["Mongolia"],["Mauritius"],["Lesotho"],["Burundi"],["Luxembourg"],["Djibouti"],["Macau"],["Republic of the Congo"],["Fiji"],["Montenegro"],["The Gambia"],["Swaziland"],["Brunei"],["Bhutan"],["Liberia"],["Timor Leste"],["Malta"],["The Bahamas"],["Equatorial Guinea"],["Iceland"],["Cabo Verde"],["Somalia"],["Guyana"],["Suriname"],["Maldives"],["Barbados"],["New Caledonia"],["French Polynesia"],["Central African Republic"],["Belize"],["Guam"],["Aruba"],["Saint Lucia"],["Antigua and Barbuda"],["Andorra"],["Guinea-Bissau"],["Solomon Islands"],["Saint Vincent and the Grenadines"],["Vanuatu"],["Comoros"],["U.S. Virgin Islands"],["Eritrea"],["Samoa"],["Grenada"],["S\u00e3o Tom\u00e9 and Pr\u00edncipe"],["Bermuda"],["Seychelles"],["Dominica"],["Cayman Islands"],["Faroe Islands"],["Saint Kitts and Nevis"],["Tonga"],["Greenland"],["Monaco"],["Micronesia, Federated States of"],["Liechtenstein"],["Marshall Islands"],["San Marino"],["Kiribati"],["Nauru"],["Tuvalu"]],"hovertemplate":"Population=%{marker.size}<br>Internet Users=%{marker.color}<br>Country or Area=%{customdata[0]}<extra></extra>","legendgroup":"","marker":{"color":[765367947,461347554,244090854,141206801,115845120,109446612,85242816,82470752,69304405,63003313,62621016,61837331,52308536,52225879,49038556,48484084,47359575,43850141,39215756,36513941,36387619,33950632,33561876,31858027,30557175,30548252,30530435,29005924,27048861,25343685,25260147,22072765,21920626,21159515,20564451,19704622,19543075,18892351,16692456,16374103,15877494,15674241,14864456,13913699,12545558,12512 ...

# %%
# Rank vs Pop Size
px.scatter(internet, 
           x= 'Population', y= 'Percentage',
           size= 'Population', 
           trendline="ols",
           title= "Population vs Percentage of it who are Internet Users", 
           color= 'Internet Users')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6ce443cf-8362-4c9f-aa31-0d98ed6f1f67" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6ce443cf-8362-4c9f-aa31-0d98ed6f1f67")) {                    Plotly.newPlot(                        "6ce443cf-8362-4c9f-aa31-0d98ed6f1f67",                        [{"hovertemplate":"Population=%{marker.size}<br>Percentage=%{y}<br>Internet Users=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[765367947,461347554,244090854,141206801,115845120,109446612,85242816,82470752,69304405,63003313,62621016,61837331,52308536,52225879,49038556,48484084,47359575,43850141,39215756,36513941,36387619,33950632,33561876,31858027,30557175,30548252,30530435,29005924,27048861,25343685,25260147,22072765,21920626,21159515,20564451,19704622,19543075,18892351,16692456,16374103,15877494,15674241,14864456,13913699,12545558,12512639,10922179,10650818,10162807,10021242,9554907,9521056,9169603,8913217,8861485,8358728,7942864,7799565,7763795,7681957,7622142,7548512,7461297,7121116,7048231,7011507,6997472,6883796,6788737,6585678,6480202,6400330,6271270,6257430,6182411,6162217,5638956,5580465,5567278,5441827,5120225,4843916,4831170,4821119,4760715,4755187,4698108,4492326,4472992,4446926,4273353,4271053,4160340,4068194,4053797,4024552,3717818,3511549,3208312,3083783,3047909,2977793,2811056,2664928,2657770,2566126,2532059,2505948,2437026,2371852,2366406,2360269,2358540,2309235,2243448,2194985,2105339,2043110,1993079,1959127,1749517,1732218,1640893,1589659,1585471,1578008,1449758,1431090,1409888,1387116,1353986,1223591,1153786,1058744,1019049,1003542,1000575,968500,963795,952369,948977,933450,924955,919398,729236,702911,665312,607311,570794,532849,517789,455055,452479,448260,416753,414278,406705,388541,377607,356356,344970,336057,332642,329196,312315,294851,290375,275785,275717,233604,226557,205746,202204,176400,132221,102285,90889,77529,76095,73148,72872,72048,71050,69020,67535,66402,66023,63692,61155,60349,55677,51467,49906,48097,44669,44558,39242,37553,37257,37201,20560,20100,16971,6475,5520],"coloraxis":"coloraxis","size":[1409517397,1339180127,324459463,209288278,127484450,143989754,263991379,129163276,82114224,104918090,66181585,220800300,64979548,80745020,81162788,50982212,95540800,97553151,46354321,69037513,59359900,36624199,44271041,56717156,190015955,49065615,164669751,38170712,32938213,31624264,44222947,35739580,23626456,24450561,31977065,41318142,104957438,38274618,31910641,53370609,17035938,32165485,18054726,18204499,19679306,40533330,28833629,24294750,42862958,11429336,9910701,16624858,57310019,9400145,49699862,10618303,8476005,11159773,9827589,8735453,10329506,28250420,9721559,20876917,9468338,81339988,10766998,16913503,8321570,7364883,9702353,11532127,29304998,18269868,8790574,29668834,11484636,24053727,5733551,16005373,5305383,11051600,5523231,5708844,17094130,6082357,15850567,7084571,16529904,5447662,4705818,29784193,6811297,35530081,4136528,4761657,4636262,4905769,4920724,4051212,19193382,9265067,4189353,3663131,12208407,18622104,2639211,25570895,3507017,4098587,3912061,3456750,18541980,6045117,2890297,21477348,2930187,2930450,6377853,8921343,6858160,6217581,2079976,2083160,1949670,11175692,12717176,1492584,2890299,6374616,10981229,5758075,1309632,1369125,2025137,12575714,7557212,14899994,7797694,1179551,2291661,2533794,8251162,4420184,3075647,1265138,2233339,10864245,583455,956985,622567,5260750,905502,628960,2100568,1367254,428697,807610,4731906,1296311,430835,395361,1267689,335025,546388,14742523,777859,563402,436330,285719,276255,283007,4659080,374681,164229,105264,178844,102012,76965,1861283,611343,109897,276244,813912,104901,5068831,196440,107825,204327,61349,94737,73925,61559,49290,55345,108020,56480,38695,105544,37922,53127,33400,116398,11359 ...

# %%
# Import Folium for plot
import folium

# Add population in millions column for better plotting
internet['pop_millions'] = internet.Population.div(1_000_000)

# Bring lat long by country
lat_long = pd.read_html('https://developers.google.com/public-data/docs/canonical/countries_csv')[0]
lat_long.reset_index(inplace=True)
# Correct Country names to match
lat_long.name.replace({'Myanmar [Burma]': 'Myanmar',
                       "Côte d'Ivoire": 'Ivory Coast',
                       "Congo [Republic]": 'Republic of the Congo',
                       "Palestinian Territories": 'Palestinian Authority',
                       "Macedonia [FYROM]": 'Macedonia',
                       "Timor-Leste": 'Timor Leste',
                       "Cape Verde": 'Cabo Verde'}, inplace=True)

internet['Country or Area'].replace({'South Sudan': 'Sudan',
                                     'Democratic Republic of the Congo': 'Republic of the Congo',
                                      'The Gambia': 'Gambia',
                                     'The Bahamas' : 'Bahamas',
                                     'Micronesia, Federated States of': 'Micronesia'}, inplace=True)

# json file for the world map
map_geo = '/content/globe.geo.json'
# Create the base map
m = folium.Map(location=[50, 0], zoom_start=3)

# Create Choropleth layer
folium.Choropleth(
    geo_data=map_geo,
    name='choropleth',
    data=internet,
    columns=['Country or Area', 'Percentage'],
    key_on='feature.properties.name',
    fill_color='Greens',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name='Internet Users(%)').add_to(m)

# Add Bubbles for the size of the country
for country in internet['Country or Area']:
  folium.CircleMarker(location= [ lat_long.query('name == @country')['latitude'].values[0], lat_long.query('name == @country')['longitude'].values[0] ],
                      radius=internet.query('`Country or Area` == @country')['Population'].values[0]/25000000,
                      color='blue',
                      fill=True, 
                      fill_color='lightblue').add_to(m)

folium.LayerControl().add_to(m)

# View
m
